# %%
import pandas as pd

# %%
def a1():
    str = """
# numpy
a = np.zeros(10, dtype=int)
b = np.ones((2,3), dtype=int) # 2x3 matrix of ones
c = np.full((2,3), 3.14) # matrix size and specific number to fill it with
d = np.arange(0,5,2) # range from 0 to 5, step size is 2
e = np.linspace(0,2,5) # start from 0 to 2, have 5 numbers equally spaced between 0 and 2
f = np.eye(3) # 3x3 identity matrix
g = np.empty((2,3)) # 2 by 3 matrix - values will be whatever is at that memory location
g.size # total elements in a numpy array - g
g.shape # dimension of a numpy array - g
g.ndim
    """
    return str

def a2():
    str = """
# numpy
np.random.randint(0, 10, (3,3))
vect = np.random.uniform(10, 90, 15).astype(int)
np.max(vect), np.mean(vect), np.sum(vect), np.sort(vect)
# concatenate
add = np.concatenate([b,c])
# splitting
x = [1, 2, 3, 99, 99, 3, 2, 1]
x1, x2, x3 = np.split (x, [3,5])
    """
    return str


def a3():
    str = """
# pandas
df = pd.read_csv('file.csv', index_col=0, header=0)
df = pd.DataFrame.from_dict(dict2)
df.rename(columns={'name':'CEO', 'age':'Time Spent on Earth (years)', 'salary':'rupees'}, inplace=True)
df.index
df.columns
df.values
df.head(2)
df.tail(2)
df.info()
df.sample(2)
df.describe()
min = df['lifeExp'].argmin() # returns index of min val
    """
    return str

def a4():
    str = """
# pandas
# loc/iloc (loc - labels, ending is inclusive, iloc - integer, ending is exclusive)
df2 = data[data['Generation']==1]
treasure_df.loc['R28', treasure_df.columns[9]]
df.loc[df.density > 100, ['population', 'area']]
treasure_df.iloc[12,12]

median = df.loc[:,'gdpPercap'].median()
mean_life_exp_top_50 = round(df.query("gdpPercap > @median").loc[:,'lifeExp'].mean(), 3)

pop_1952 = df.query("year == 1952").loc[:,'pop'].sum()
val = treasure_df.query("C1 < C2").loc[:,"C1"]
''.join(val)
val = treasure_df.loc['R19':'R26', 'C26'].values
''.join(val)
    """
    return str

def a5():
    str = """
df2['Generation'].value_counts() # count of each value in column

dirty['country'] = dirty['country'].replace('china', 'China')
first = len(df[df['Category'] == list(df['Category'].unique())[0]]['Category'])

df['at'] = pd.to_datetime(df['at'], format='%Y-%m-%d %H:%M:%S')
count_months = df[(df['at'].dt.year == 2021)]['at'].dt.month.value_counts().sort_index()

df.dropna(subset=['foo'], axis=0, inplace=True)
df.foo.fillna(1, inplace=True)
df.foo.replace(np.nan, 0, inplace=True)

df.isnull(), df.notnull(), 

df.duplicated()
df.drop_duplicates(['k1','k2'], inplace=True)

df.groupby('col_name')

df.col_name.map(), df.col_name.mapapply(), df.col_name.apply()

pd.concat([list of df's])

df['Name'].str.len()
df['Email'].str.upper()
df['Email'].str.contains('gmail')
df['Email'].str.split('@').str[0]

str()
strftime(value, format=)
datetime.strptime(value,format=)
    """
    return str
