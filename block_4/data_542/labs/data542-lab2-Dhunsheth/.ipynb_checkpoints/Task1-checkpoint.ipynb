# %% [markdown]
# # Task 1: Treasure hunt with Pandas
# ---

# %% [markdown]
# Learning how to index with Pandas is kind of like having to eat your vegetables: it's not the funnest thing, but you need to know it! In this exercise, I'll provide you with clues that you need to use to index a dataframe and find the "Treasure". For example, if the clue is "The first ten rows" then you might try:
#
# ```python
# >>> df.iloc[:10]
# ```
#
# The above is just an example, but the result of your indexing should always be the string `'TREASURE'`.

# %%
import pandas as pd

# %% [markdown]
# ## 1.1

# %% [markdown]
# Load in the file `treasure_hunt.csv` as a dataframe called `treasure_df`. Read in the first column as the dataframe index column and the first row as the dataframe columns.

# %%
# Your solution here
treasure_df = pd.read_csv('./Data/treasure_hunt.csv', index_col=0, header=0)
treasure_df
# Out:
#            C1 C2 C3 C4 C5 C6 C7 C8 C9       C10  ... C21 C22 C23 C24 C25 C26  \
# R1          T  W  W  R  A  L  E  A  J         B  ...   H   A   Q   O   S   Q
# R2          U  R  O  N  Y  D  K  N  K         T  ...   T   D   M   D   W   F
# R3          X  H  E  F  T  C  Y  Z  O         B  ...   J   X   S   K   P   A
# R4          R  Q  E  A  W  D  X  T  Z         K  ...   Y   C   Y   W   P   I
# R5          R  G  Q  Z  S  L  W  U  W         Q  ...   Z   N   J   R   Z   G
# R6          R  U  B  X  T  U  J  V  E         Q  ...   U   P   J   F   L   U
# R7          W  U  E  N  M  O  R  K  E         R  ...   Q   O   H   G   Z   G
# R8          T  P  R  W  E  D  A  E  S         I  ...   N   A   L   J   U   Y
# R9          E  T  O  J  U  O  M  A  W         B  ...   X   Z   B   N   M   A
# R10         G  F  H  N  Z  K  G  R  J         Q  ...   G   G   T   Q   L   Q
# R11         Z  R  K  A  R  D  W  I  K         S  ...   D   Z   I   M   A   Y
# R12         Y  F  A  F  C  T  A  O  N         K  ...   L   V   A   K   E   B
# R13         A  R  W  P  J  S  M  J  D         A  ...   U   W   U   M   B   A
# R14         X  W  G  I  O  K  D  G  L         N  ...   G   S   G   Q   H   D
# R15         N  L  Q  V  P  A  B  H  Y         H  ...   A   U   O   S   O   V
# R16         X  R  S  X  Z  O  V  T  R         P  ...   V   F   N   B   E   W
# R17         S  T  L  E  I  B  H  S  K         G  ...   P   Y   F   H   G   Z
# R18         U  Z  I  L  O  C  F  F  S         Q  ...   C   U   W   I   B   F
# R19         P  F  T  O  Q  J  U  C  X         F  ...   Y   H   Q   I   G   T
# R20  TREASURE  K  E  F  G  O  S  Q  D         J  ...   Q   B   K   G   H   R
# R21         S  D  K  D  M  D  S  E  I         Q  ...   Y   Y   N   M   O   E
# R22         W  N  J  K  W  J  L  G  M         R  ...   P   W   N   Y   B   A
# R23         V  A  V  O  R  Z  L  D  T         V  ...   Z   I   E   J   Y   S
# R24         H  G  V  T  Z  D  X  O  C         Q  ...   Z   N   C   F   N   U
# R25         R  S  R  H  O  W  A  E  F         K  ...   D   Q   W   P   O   R
# R26         U  D  H  D  N  U  K  J  W         K  ...   X   K   J   H   S   E
# R27         Z  G  E  R  D  Y  V  T  O         N  ...   F   W   A   K   L   V
# R28         R  F  T  M  U  C  S  G  B  TREASURE  ...   F   E   N   D   X   A
# R29         T  N  S  Z  Y  O  F  P  Q         T  ...   F   E   Q   D   K   W
# R30         E  Z  Z  F  Z  Z  M  N  Z         Z  ...   Z   Z   Z   Z   Z   Z
#
#     C27 C28   C29   C30
# R1    C   N  TREA  SURE
# R2    N   I     E     A
# R3    I   E     S     U
# R4    G   B     R     E
# R5    M   P     Q     Y
# R6    Y   U     H     O
# R7    Y   P     C     F
# R8    F   D     U     H
# R9    N   Q     J     O
# R10   W   H     N     T
# R11   Q   R     J     Q
# R12   X   V     U     S
# R13   T   U     Y     X
# R14   P   Y     B     T
# R15   D   Y     N     C
# R16   N   F     H     L
# R17   J   X     C     S
# R18   M   X     D     Q
# R19   B   H     M     V
# R20   Q   T     S     H
# R21   M   P     C     K
# R22   O   H     W     A
# R23   S   J     C     X
# R24   I   J     U     R
# R25   D   E     J     L
# R26   Q   S     O     I
# R27   O   S     E     L
# R28   S   S     B     R
# R29   Q   U     F     W
# R30   Z   Z     Z     Z
#
# [30 rows x 30 columns]

# %% [markdown]
# ## 1.2

# %% [markdown]
# **CLUE:** C20, R1

# %%
# Your solution here
treasure_df.loc['R1', 'C20']
# Out:
# 'TREASURE'

# %% [markdown]
# ## 1.3

# %% [markdown]
# **CLUE:** thirteenth column, thirteenth row (*hint*: recall that indexing starts at 0!)

# %%
# Your solution here
treasure_df.iloc[12,12]
# Out:
# 'TREASURE'

# %% [markdown]
# ## 1.4

# %% [markdown]
# **CLUE:** R28, tenth column

# %%
# Your solution here
treasure_df.loc['R28', treasure_df.columns[9]]
# Out:
# 'TREASURE'

# %% [markdown]
# ## 1.5
# rubric={autograde:1}

# %% [markdown]
# # Your solution here**CLUE:** C26, R19 to R26
#
# **HINT:** You might need to do a bit of extra wrangling (e.g. joining stuff, maybe?) to get a result of "TREASURE" here...

# %%
# Your solution here
val = treasure_df.loc['R19':'R26', 'C26'].values
''.join(val)
# Out:
# 'TREASURE'

# %% [markdown]
# ## 1.6

# %% [markdown]
# **CLUE:** The first rows of C29 *plus* the first row of C30

# %%
# Your solution here
treasure_df.loc[:,'C29'].values[0] + treasure_df.loc[:,'C30'].values[0]
# Out:
# 'TREASURE'

# %% [markdown]
# ## 1.7

# %% [markdown]
# **CLUE:** The first row of all columns that **do not** have a "Z" in the last row.
#
# **HINT:** You might need to do a bit of extra wrangling to get a result of "TREASURE" here...

# %%
# Your solution here
val = ''
for i in range(len(treasure_df.iloc[0,:])):
    if treasure_df.iloc[:,i].values[len(treasure_df.iloc[:,i])-1] != 'Z':
        val += treasure_df.iloc[:,i].values[0]
print(val)
# Out:
# TREASURE

# %% [markdown]
# ## 1.8

# %% [markdown]
# **CLUE:** C1 for C1 < C2 (remember, in Python, comparison operators work on string too, e.g., `"a" < "b" = True` because `a` occurs before `b` alphabetically. Also, don't forget about `.query()`!)
#
# **HINT:** You might need to do a bit of extra wrangling to get a result of "TREASURE" here...

# %%
# Your solution here
val = treasure_df.query("C1 < C2").loc[:,"C1"]
''.join(val)
# Out:
# 'TREASURE'
